# %%
import pandas as pd

results_df = pd.read_csv('clustering_results.csv')
results_df.describe()
# Out:
#        n_neighbors  n_components    min_dist  min_cluster_size  min_samples  \
# count   121.000000    121.000000  121.000000        121.000000   121.000000
# mean     29.000000     25.000000    0.062727         25.000000    15.727273
# std       3.175426      2.345208    0.047697          3.175426     2.425558
# min      24.000000     21.000000    0.000000         20.000000    12.000000
# 25%      26.000000     23.000000    0.020000         22.000000    14.000000
# 50%      29.000000     25.000000    0.050000         25.000000    15.000000
# 75%      32.000000     27.000000    0.100000         28.000000    18.000000
# max      34.000000     29.000000    0.150000         30.000000    20.000000
#
#        silhouette_score  davies_bouldin_score  calinski_harabasz_score
# count        121.000000            121.000000               121.000000
# mean           0.454307              0.532917             12261.440539
# std            0.047114              0.036071              4255.895901
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
selected_columns = ['n_neighbors', 'n_components', 'min_dist', 'silhouette_score', 'davies_bouldin_score', 'calinski_harabasz_score']
sns.pairplot(results_df[selected_columns])
plt.show()
